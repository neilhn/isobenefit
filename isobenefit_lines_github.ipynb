# %% [markdown]
# # Libraries

# %%
## LIBRARIES
import numpy as np                   # for mathematical functions
import networkx as nx                # for network analysis
import matplotlib.pyplot as plt      # for plotting
import json                          # for loading JSON files
import fiona                         # for loading shapefiles
import osmnx as ox                   # for obtaining graph from OSM data
import pandas as pd                  # for working with common data formats like CSV
from pyproj import Proj, transform   # for converting coordinates
from time import gmtime, strftime    # for print time marks
import pickle                        # for write/read lists to/from file
import utm                           # for conversion of latitude and longitude to metric coordinates

# %%
plt.rcParams['figure.figsize']=[20,15]

# %%
import road_analysis as RA

# %% [markdown]
# # Road network data

# %%
G=RA.load_picke('Piedmont_CA_roads.pickle')

# %% [markdown]
# # Benefit centres

# %%
B=[(566300,4186550,80,500),
   (567100,4186200,100,500),
   (567800,4186100,50,500),
   (569100,4185900,30,500)]

# %%
RA.plot_roads(G)

# %% [markdown]
# # Continuum version of isobenefit lines

# %%
RA.isobenefit_continuum(G,B)

# %% [markdown]
# # Network-based version of isobeneit lines

# %%
RA.isobenefit_network(G,B,metric=True)
